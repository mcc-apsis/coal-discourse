# %%
import matplotlib.pylab as plt
import numpy as np
import pandas as pd
import time
import sys
import os

import seaborn as sns
import matplotlib.dates as mdates
from datetime import datetime, date

# preamble for jupyter notebook and django
import django
import platform

if platform.node() == "srv-mcc-apsis":
    sys.path.append("/home/muef/tmv/BasicBrowser/")
    #sys.path.append('/home/leey/tmv/BasicBrowser/')
    dtm_path = "/home/galm/software/dtm/dtm/main"
else:
    # local paths
    sys.path.append('/media/Data/MCC/tmv/BasicBrowser/')
    dtm_path = "/home/finn/dtm/dtm/main"

os.environ.setdefault("DJANGO_SETTINGS_MODULE", "BasicBrowser.settings")
django.setup()

# import from appended path
import parliament.models as pm
from parliament.tasks import do_search, run_tm, combine_searches
import cities.models as cmodels
from django.contrib.auth.models import User
from tmv_app.models import *
import scoping.models as sm
from utils.tm_mgmt import update_topic_scores
from django.db.models import Q, Count, Func, F, Sum, Avg, Value as V
from django.db.models.functions import TruncDate, TruncMonth, TruncYear

from utils.topic_comparison import compare_topic_queryset, save_res, sort_matrix, draw_score_matrix
from utils.topic_comparison import save_topic_list_as_table, draw_bipartite_topic_graph, bipartite_graph_from_matrix

# %%
runs = RunStats.objects.filter(psearch__id=89, method='BD', top_chain_var=0.01, status=3).order_by('alpha')

run_ids = [run.run_id for run in runs]
run_df = pd.DataFrame.from_dict(runs.values('run_id', 'K', 'alpha',
                                'top_chain_var', 'rng_seed', 'max_iter', 'psearch__id', 'coherence', 'exclusivity',))

#run_df.set_index('run_id')
run_df = run_df.sort_values('run_id').set_index('run_id')
#run_df[run_df["K"]== 45]
run_df
# Out:
#          K  alpha  coherence  exclusivity  max_iter  psearch__id  rng_seed  \
# run_id
# 2155    45   0.01   0.464178     0.878157        50           89         1
# 2156    45   0.05   0.473385     0.912385        50           89         1
# 2157    45   0.10   0.482888     0.901765        50           89         1
# 2350    35   0.01   0.419955     0.804016       200           89         1
# 2351    40   0.01   0.458939     0.868018       200           89         1
# 2352    45   0.01   0.480687     0.928956       200           89         1
# 2353    40   0.05   0.467016     0.869076       200           89         1
# 2363    40   0.02   0.461092     0.861722       200           89         1
# 2383    35   0.05        NaN          NaN       200           89         1
# 2661    35   0.01        NaN          NaN       200           89         1
#
#         top_chain_var
# run_id
# 2155             0.01
# 2156             0.01
# 2157             0.01
# 2350             0.01
# 2351             0.01
# 2352             0.01
# 2353             0.01
# 2363             0.01
# 2383             0.01
# 2661             0.01

# %%
Topic.objects.filter(run_id=2155).values('id')
# Out:
# <QuerySet [{'id': 178500}, {'id': 178506}, {'id': 178504}, {'id': 178495}, {'id': 178473}, {'id': 178483}, {'id': 178486}, {'id': 178472}, {'id': 178477}, {'id': 178480}, {'id': 178498}, {'id': 178507}, {'id': 178505}, {'id': 178502}, {'id': 178508}, {'id': 178511}, {'id': 178482}, {'id': 178512}, {'id': 178497}, {'id': 178503}, '...(remaining elements truncated)...']>

# %% [markdown]
# # get similarity matrices

# %%
from sklearn.metrics.pairwise import cosine_similarity

def topic_cosine_similarity(run_ids, period='all'):

    df = pd.DataFrame.from_dict(TopicTerm.objects.filter(run_id__in=run_ids).order_by('run_id', '-topic__score').values('topic', 'term__title', 'score', 'PY'))
    
    if period == 'all':
        # sum over periods
        df = df.groupby(['topic', 'term__title']).sum()
    else:
        #  select period
        df = df[df['PY'] == period].groupby(['topic', 'term__title']).sum()

    sdf = df['score'].unstack(level=0, fill_value=0).to_sparse(fill_value=0)
    print("word matrix density: {}".format(sdf.density))
    
    sim = cosine_similarity(sdf.values.T)
    topic_ids = [topic_id for topic_id in sdf.columns]
    
    print("shape: {}".format(sim.shape))
    return sim, topic_ids

from sklearn.metrics.pairwise import linear_kernel

def topic_topword_overlap(run_ids, period='all', no_topwords=20):

    tw_dicts = []
    for t in Topic.objects.filter(run_id__in=run_ids).order_by('run_id','-score'):
        
        if not t.top_words:
            print("assign top words (average, not taking topic shares into account!) for topic {}".format(t))
            terms = Term.objects.filter(topicterm__topic=t).values('title').annotate(
                        summed_score = Sum(F('topicterm__score'))).order_by('-summed_score')[:no_topwords]
            term_list = [term['title'] for term in terms]
            t.top_words = term_list
            t.save()

        for term in t.top_words:
            tw_dicts.append({'topic': t.id, 'term': term, 'value': 1}) 

    df = pd.DataFrame.from_dict(tw_dicts)

    df = df.groupby(['topic', 'term']).sum()

    df = df['value'].unstack(level=0, fill_value=0)
    
    sim = linear_kernel(df.values.T)
    topic_ids = [topic_id for topic_id in df.columns]

    print("shape: {}".format(sim.shape))
    
    return sim, topic_ids

# %%
save_dir = "./plots/bipartite_graphs/"

# %%
# run ids need to be provided in ascending order
run_ids = [2350, 2661]
#runs = [2155, 2156, 2157]
runs = RunStats.objects.filter(run_id__in=run_ids).order_by('run_id')
run_ids = [run.run_id for run in runs]
Ks = [run.K for run in runs]
tk = np.array(Ks).cumsum()
#topic_labels = {item['id']: item['title'] for item in Topic.objects.filter(run_id__in=selected_run_ids).values('title', 'id')}
print(run_ids)
print(Ks)
print(tk)
# Out:
# [2350, 2661]
# [35, 35]
# [35 70]

# %%
cos_sim, topic_ids_cos = topic_cosine_similarity(run_ids)
plt.imshow(cos_sim)
plt.colorbar()
# Out:
# word matrix density: 0.07158945724695973
# shape: (70, 70)

# %%
overlap_sim, topic_ids_overlap = topic_topword_overlap(run_ids)
plt.imshow(overlap_sim)
plt.colorbar()
# Out:
# assign top words (average, not taking topic shares into account!) for topic {red, tun, wirklich}
# assign top words (average, not taking topic shares into account!) for topic {darauf, bereich, natur}
# assign top words (average, not taking topic shares into account!) for topic {wirtschaft, entwickl, bundesregier}
# assign top words (average, not taking topic shares into account!) for topic {polit, freiheit, staat}
# assign top words (average, not taking topic shares into account!) for topic {million, milliard, haushalt}
# assign top words (average, not taking topic shares into account!) for topic {wirtschaft, deutschland, wachstum}
# assign top words (average, not taking topic shares into account!) for topic {euro, sozialpolit, milliard}
# assign top words (average, not taking topic shares into account!) for topic {deutsch, deutschland, franzos}
# assign top words (average, not taking topic shares into account!) for topic {energi, erneuerbar, kohl}
# assign top words (average, not taking topic shares into account!) for topic {wettbewerb, preis, markt}
# assign top words (average, not taking topic shares into account!) for topic {international, klimaschutz, prozent}
# assign top words (average, not taking topic shares into account!) for topic {steu, burg, gemeind}
# assign top words (average, not taking topic shares into account!) for topic {gesetz, grun, verordn}
# assign top words (average, not taking topic shares into account!) for topic {million, tonn, kohl}
# assign top words (average, not taking topic shares into account!) for topic {unternehm, klein, mittl}
# assign top words (average, not taking topic shares into account!) for topic {bundeskanzl, berlin, polit}
# assign top words (average, not taking topic shares into account!) for topic {energiepolit, braunkohl, steinkohl}
# assign top words (average, not taking topic shares into account!) for topic {europa, kommission, gemeinschaft}
# assign top words (average, not taking topic shares into account!) for topic {haushalt, bundesfinanzminist, milliard}
# assign top words (average, not taking topic shares into account!) for topic {spd, grun, atomenergi}
# assign top words (average, not taking topic shares into account!) for topic {unternehm, arbeitnehm, gesetz}
# assign top words (average, not taking topic shares into account!) for topic {bundesregier, gesetz, bundestag}
# assign top words (average, not taking topic shares into account!) for topic {kernenergi, kernkraftwerk, ausstieg}
# assign top words (average, not taking topic shares into account!) for topic {ost, gebiet, bundesland}
# assign top words (average, not taking topic shares into account!) for topic {arbeitslos, sozial, okolog}
# assign top words (average, not taking topic shares into account!) for topic {europa, staat, vereinigt}
# assign top words (average, not taking topic shares into account!) for topic {umweltpolit, umweltschutz, luft}
# assign top words (average, not taking topic shares into account!) for topic {gesetz, gesetzentwurf, entwurf}
# assign top words (average, not taking topic shares into account!) for topic {saar, saarland, nordrheinwestfal}
# assign top words (average, not taking topic shares into account!) for topic {bundesbahn, bahn, strass}
# assign top words (average, not taking topic shares into account!) for topic {sozial, jung, famili}
# assign top words (average, not taking topic shares into account!) for topic {bergbau, bergleut, subvention}
# assign top words (average, not taking topic shares into account!) for topic {landwirtschaft, bau, landlich}
# assign top words (average, not taking topic shares into account!) for topic {entwicklungsland, rohstoff, entwicklungshilf}
# assign top words (average, not taking topic shares into account!) for topic {forschung, wissenschaft, ministerium}
# shape: (70, 70)

# %% [markdown]
# # sort topics according to match

# %%
K_run_id = [run.K for run in RunStats.objects.filter(run_id__in=run_ids).order_by('run_id')]
if K_run_id[0] > K_run_id[1]:
    corr_matrix = cos_sim[tk[0]:tk[1], :tk[0]]
    topics1 = [Topic.objects.get(id=topic_id) for topic_id in topic_ids_cos[tk[0]:tk[1]]]
    topics2 = [Topic.objects.get(id=topic_id) for topic_id in topic_ids_cos[0:tk[0]]]
else:
    corr_matrix = cos_sim[tk[0]:tk[1], :tk[0]].T
    topics1 = [Topic.objects.get(id=topic_id) for topic_id in topic_ids_cos[0:tk[0]]]
    topics2 = [Topic.objects.get(id=topic_id) for topic_id in topic_ids_cos[tk[0]:tk[1]]]
    
filename = "cosine_similarity_matrix_runs_{}_{}.png".format(run_ids[0], run_ids[1])
draw_score_matrix(corr_matrix, topics1, topics2, match=True, filename=os.path.join(save_dir, filename))
# Out:
# matching sum:	23.741983511889
# max rows:	25.00696364090212
# max cols:	25.884393593975233
# 0

# %%
filename = "top_word_overlap_matrix_runs_{}_{}.png".format(run_ids[0], run_ids[1])
draw_score_matrix(overlap_sim[tk[0]:tk[1], :tk[0]], topics1, topics2, match=True, filename=os.path.join(save_dir, filename))
# Out:
# matching sum:	360.0
# max rows:	382.0
# max cols:	382.0
# 0

# %% [markdown]
# # todo: in draw function, sort according to topic scores for one model

# %% [markdown]
# # plot bipartite graph

# %%
# !!! not correctly working at the moment for different Ks

# todo: in draw function, sort according to topic scores for one model

K_run_id = [run.K for run in RunStats.objects.filter(run_id__in=run_ids).order_by('run_id')]
if K_run_id[0] >= K_run_id[1]:
    corr_matrix = cos_sim[tk[0]:tk[1], :tk[0]]
    topics1 = [Topic.objects.get(id=topic_id) for topic_id in topic_ids_cos[tk[0]:tk[1]]]
    topics2 = [Topic.objects.get(id=topic_id) for topic_id in topic_ids_cos[0:tk[0]]]
else:
    corr_matrix = cos_sim[tk[0]:tk[1], :tk[0]].T
    topics1 = [Topic.objects.get(id=topic_id) for topic_id in topic_ids_cos[0:tk[0]]]
    topics2 = [Topic.objects.get(id=topic_id) for topic_id in topic_ids_cos[tk[0]:tk[1]]]

g = bipartite_graph_from_matrix(corr_matrix, topics1, topics2, match=True, threshold=0.2)

filename='cosine_similarity_graph_runs_{}_{}'.format(run_ids[0], run_ids[1])
draw_bipartite_topic_graph(g, filename=os.path.join(save_dir, filename), figsize=(12, 8))
print("saved as " + os.path.join(save_dir, filename))
# Out:
# matching sum:	23.741983511889003
# max rows:	25.884393593975233
# max cols:	25.00696364090212
# Topic labels: {0: <Topic: {umweltpolit, umweltschutz, luft}>, 1: <Topic: {unternehm, arbeitnehm, gesetz}>, 2: <Topic: {wirtschaft, entwickl, bundesregier}>, 3: <Topic: {landwirtschaft, bau, landlich}>, 4: <Topic: {international, klimaschutz, prozent}>, 5: <Topic: {ost, gebiet, bundesland}>, 6: <Topic: {bergbau, bergleut, subvention}>, 7: <Topic: {europa, kommission, gemeinschaft}>, 8: <Topic: {unternehm, klein, mittl}>, 9: <Topic: {energiepolit, braunkohl, steinkohl}>, 10: <Topic: {red, tun, wirklich}>, 11: <Topic: {darauf, bereich, natur}>, 12: <Topic: {forschung, wissenschaft, ministerium}>, 13: <Topic: {bundesbahn, bahn, strass}>, 14: <Topic: {kernenergi, kernkraftwerk, ausstieg}>, 15: <Topic: {spd, grun, atomenergi}>, 16: <Topic: {wettbewerb, preis, markt}>, 17: <Topic: {arbeitslos, sozial, okolog}>, 18: <Topic: {gesetz, grun, verordn}>, 19: <Topic: {europa, staat, vereinigt}>, 20: <Topic: {entwicklungsland, rohstoff, entwicklungshilf}>, 21: <Topic: {saar, saarland, nordrheinwestfal}>, 22: <Topic: {bundesregier, gesetz, bundestag}>, 23: <Topic: {polit, freiheit, staat}>, 24: <Topic: {deutsch, deutschland, franzos}>, 25: <Topic: {haushalt, bundesfinanzminist, milliard}>, 26: <Topic: {bundeskanzl, berlin, polit}>, 27: <Topic: {million, milliard, haushalt}>, 28: <Topic: {sozial, jung, famili}>, 29: <Topic: {energi, erneuerbar, kohl}>, 30: <Topic: {wirtschaft, deutschland, wachstum}>, 31: <Topic: {gesetz, gesetzentwurf, entwurf}>, 32: <Topic: {euro, sozialpolit, milliard}>, 33: <Topic: {steu, burg, gemeind}>, 34: <Topic: {million, tonn, kohl}>, 35: <Topic: environmental protection>, 36: <Topic: debate government policy>, 37: <Topic: economic policy>, 38: <Topic: agricultural policy>, 39: <Topic: green policies>, 40: <Topic: reunification>, 41: <Topic: coal mining>, 42: <Topic: European Coal & Steel Community>, 43: <Topic: subsidy reduction>, 44: <Topic: nuclear phase-out>, 45: <Topic: common terms>, 46: <Topic: procedural>, 47: <Topic: research & development>, 48: <Topic: transport policy>, 49: <Topic: risks of nuclear energy>, 50: <Topic: fiscal reform>, 51: <Topic: energy transition & power market>, 52: <Topic: job market>, 53: <Topic: procedural 2>, 54: <Topic: international cooperation>, 55: <Topic: natural resources>, 56: <Topic: hard coal & subsidies>, 57: <Topic: structural adjustment>, 58: <Topic: policy statements>, 59: <Topic: foreign policy>, 60: <Topic: budget 2>, 61: <Topic: federal government>, 62: <Topic: budget>, 63: <Topic: housing & social security>, 64: <Topic: energy supply mix>, 65: <Topic: economic policy 2>, 66: <Topic: economic policy & participation>, 67: <Topic: climate protection>, 68: <Topic: tax policy>, 69: <Topic: coal policy & prices>}
# saved as ./plots/bipartite_graphs/cosine_similarity_graph_runs_2350_2661

# %%
# compare settings

fields = RunStats._meta.get_fields()
runs = RunStats.objects.filter(run_id__in=run_ids)

df = pd.DataFrame(list(runs.values()))

# get all field names
#for field in fields:
#    print(field.name)

df = df.transpose()
df['comparison'] = np.where(df[0] == df[1], True, False)
df
# Out:
#                                                                            0  \
# K                                                                         35
# alpha                                                                   0.01
# batch_count                                                                0
# beta                                                                    None
# citations                                                              False
# coherence                                                           0.419955
# db                                                                      True
# db_time                                                                    0
# doc_topic_scaled_score                                                 False
# docs_seen                                                                  1
# dt_threshold                                                          0.0005
# dt_threshold_scaled                                                     0.01
# dyn_win_threshold                                                        0.1
# empty_topics                                                            None
# error                                                                      0
# errortype                                                               None
# exclusivity                                                         0.804016
# extra_stopwords            [stimmt, ganz, schreib, drucksach, kolleg, ges...
# fancy_tokenization                                                     False
# fulltext                                                               False
# iterations                                                              None
# language                                                              german
# last_update                                 2019-08-29 15:52:35.128319+00:00
# lda_learning_method                                                       ba
# lda_library                                                               sk
# limit                                                                      0
# max_df                                                                  0.95
# max_features                                                           20000
# max_iter                                                                 200
# max_topics                                                              None
# method                                                                    BD
# min_freq                                                                   5
# ngram                                                                      1
# nmf_time                                                                   0
# notes                                                                   None
# parent_run_id                                                           2350
# process_id                                                              None
# psearch_id                                                                89
# query_id                                                                None
# rng_seed                                                                   1
# run_id                                                                  2350
# runtime                                               2 days 01:39:06.640515
# start                                       2019-08-27 14:13:28.139227+00:00
# status                                                                     3
# term_count                                                             20000
# tfidf_time                                                                 0
# top_chain_var                                                           0.01
# topic_scores_current                                                   False
# topic_titles_current                                                   False
# topic_year_scores_current                                              False
#
#                                                                            1  \
# K                                                                         35
# alpha                                                                   0.01
# batch_count                                                                0
# beta                                                                    None
# citations                                                              False
# coherence                                                           0.463411
# db                                                                      True
# db_time                                                                    0
# doc_topic_scaled_score                                                 False
# docs_seen                                                               9167
# dt_threshold                                                          0.0005
# dt_threshold_scaled                                                     0.01
# dyn_win_threshold                                                        0.1
# empty_topics                                                            None
# error                                                                      0
# errortype                                                               None
# exclusivity                                                         0.685325
# extra_stopwords            [stimmt, ganz, schreib, drucksach, kolleg, ges...
# fancy_tokenization                                                     False
# fulltext                                                               False
# iterations                                                              None
# language                                                              german
# last_update                                 2019-12-18 13:22:22.617400+00:00
# lda_learning_method                                                       ba
# lda_library                                                               sk
# limit                                                                      0
# max_df                                                                  0.95
# max_features                                                               0
# max_iter                                                                 200
# max_topics                                                              None
# method                                                                    BD
# min_freq                                                                   5
# ngram                                                                      1
# nmf_time                                                                   0
# notes                                                                   None
# parent_run_id                                                           2661
# process_id                                                              None
# psearch_id                                                                89
# query_id                                                                None
# rng_seed                                                                   1
# run_id                                                                  2661
# runtime                                               2 days 00:30:05.041361
# start                                       2019-12-16 12:52:17.546308+00:00
# status                                                                     3
# term_count                                                             33670
# tfidf_time                                                                 0
# top_chain_var                                                           0.01
# topic_scores_current                                                   False
# topic_titles_current                                                   False
# topic_year_scores_current                                              False
#
#                            comparison
# K                                True
# alpha                            True
# batch_count                      True
# beta                            False
# citations                        True
# coherence                       False
# db                               True
# db_time                          True
# doc_topic_scaled_score           True
# docs_seen                       False
# dt_threshold                     True
# dt_threshold_scaled              True
# dyn_win_threshold                True
# empty_topics                    False
# error                            True
# errortype                       False
# exclusivity                     False
# extra_stopwords                 False
# fancy_tokenization               True
# fulltext                         True
# iterations                      False
# language                         True
# last_update                     False
# lda_learning_method              True
# lda_library                      True
# limit                            True
# max_df                           True
# max_features                    False
# max_iter                         True
# max_topics                      False
# method                           True
# min_freq                         True
# ngram                            True
# nmf_time                         True
# notes                           False
# parent_run_id                   False
# process_id                      False
# psearch_id                       True
# query_id                        False
# rng_seed                         True
# run_id                          False
# runtime                         False
# start                           False
# status                           True
# term_count                      False
# tfidf_time                       True
# top_chain_var                    True
# topic_scores_current             True
# topic_titles_current             True
# topic_year_scores_current        True

# %% [markdown]
# # loop over pairs of model runs

# %%
from itertools import combinations
from scipy.special import binom

run_id_list = [2155, 2156, 2157] # top_chain_var = 0.01
run_id_list = [2155, 2158]
run_pairs = list(combinations(run_id_list, 2))

print(run_pairs)
print(len(run_pairs), binom(len(run_id_list), 2))
# Out:
# [(2155, 2158)]
# 1 1.0

# %%
# todo: update with changed functions (see above)

for selected_run_ids in run_pairs:
    
    Ks = [RunStats.objects.get(run_id=run_id).K for run_id in selected_run_ids]
    tk = np.array(Ks).cumsum()
    
    cos_sim, topic_ids_cos = topic_cosine_similarity(selected_run_ids)
    
    topics1 = [Topic.objects.get(id=topic_id) for topic_id in topic_ids_cos[0:tk[0]]]
    topics2 = [Topic.objects.get(id=topic_id) for topic_id in topic_ids_cos[tk[0]:tk[1]]]

    filename = "cosine_similarity_matrix_runs_{}_{}.png".format(selected_run_ids[0], selected_run_ids[1])
    draw_score_matrix(cos_sim[tk[0]:tk[1], :tk[0]], topics2, topics1, match=True, filename=os.path.join(save_dir, filename))
    
    cos_sim_sorted, permutation = sort_matrix(cos_sim[tk[0]:tk[1], :tk[0]])

    g = bipartite_graph_from_matrix(cos_sim_sorted, threshold=0.2)

    perm_topic_list = [topics2[int(permutation[i])].title for i in range(Ks[1])]

    filename='cosine_similarity_graph_runs_{}_{}'.format(selected_run_ids[0], selected_run_ids[1])
    draw_bipartite_topic_graph(g, perm_topic_list, topics1, filename=os.path.join(save_dir, filename))
# Out:
# word matrix density: 0.05582593758946464
# shape: (90, 90)
# matching sum:	38.59115946682549
# max rows:	38.979058963052665
# max cols:	40.771039270454004
# matching sum:	38.59115946682549
# max rows:	38.979058963052665
# max cols:	40.771039270454004

# %%
# similarity of all models
cos_sim, topic_ids_cos = topic_cosine_similarity(run_id_list)
plt.imshow(cos_sim)
plt.colorbar()
# Out:
# word matrix density: 0.048264744591956614
# shape: (270, 270)

# %% [markdown]
# # compress folder

# %%
# %%bash
# zip -r plots/bipartite_graphs.zip plots/bipartite_graphs
# Out:
#   adding: plots/bipartite_graphs/ (stored 0%)
#   adding: plots/bipartite_graphs/bipartite_topic_graph_Kohle_NM_K40_stopword_jahr_topword_score.pdf (deflated 27%)
#   adding: plots/bipartite_graphs/bipartite_topic_graph_Kohle_LD_K30_K40_topword_score.png (deflated 3%)
#   adding: plots/bipartite_graphs/cosine_similarity_graph_runs_2156_2157.png (deflated 5%)
#   adding: plots/bipartite_graphs/bipartite_topic_graph_Kohle_LD_K40_stopword_jahr_topword_score.png (deflated 3%)
#   adding: plots/bipartite_graphs/bipartite_topic_graph_Kohle_LD_K40_stopword_jahr_topword_score.pdf (deflated 21%)
#   adding: plots/bipartite_graphs/bipartite_topic_graph_Kohle_NM_K40_stopword_frequency_5_topword_score.png (deflated 5%)
#   adding: plots/bipartite_graphs/cosine_similarity_graph_runs_2155_2156.png (deflated 5%)
#   adding: plots/bipartite_graphs/bipartite_topic_graph_Kohle_NM_K40_stopword_herr_topword_score.png (deflated 5%)
#   adding: plots/bipartite_graphs/cosine_similarity_graph_runs_2155_2157.pdf (deflated 25%)
#   adding: plots/bipartite_graphs/bipartite_topic_graph_Kohle_LD_K40_stopword_mehr_topword_score.png (deflated 3%)
#   adding: plots/bipartite_graphs/bipartite_topic_graph_Kohle_NM_K40_stopword_jahr_topword_score.png (deflated 4%)
#   adding: plots/bipartite_graphs/bipartite_topic_graph_Kohle_LD_K40_stopword_['herr', 'jahr', 'mehr']_topword_score.png (deflated 4%)
#   adding: plots/bipartite_graphs/bipartite_topic_graph_Kohle_NM_K30_K40_topword_score.pdf (deflated 28%)
#   adding: plots/bipartite_graphs/bipartite_topic_graph_Kohle_LD_K40_stopword_herr_topword_score.pdf (deflated 21%)
#   adding: plots/bipartite_graphs/bipartite_topic_graph_Kohle_LD_K40_K50_topword_score.png (deflated 3%)
#   adding: plots/bipartite_graphs/bipartite_topic_graph_Kohle_LD_K40_stopword_frequency_5_topword_score.png (deflated 4%)
#   adding: plots/bipartite_graphs/cosine_similarity_matrix_runs_2155_2156.png (deflated 8%)
#   adding: plots/bipartite_graphs/bipartite_topic_graph_Kohle_NM_K40_stopword_frequency_5_topword_score.pdf (deflated 27%)
#   adding: plots/bipartite_graphs/bipartite_topic_graph_Kohle_LD_K20_K30_topword_score.png (deflated 3%)
#   adding: plots/bipartite_graphs/bipartite_topic_graph_Kohle_NM_K40_stopword_mehr_topword_score.png (deflated 5%)
#   adding: plots/bipartite_graphs/top_word_overlap_matrix_runs_2145_2146.png (deflated 9%)
#   adding: plots/bipartite_graphs/bipartite_topic_graph_Kohle_LD_K40_stopword_herr_topword_score.png (deflated 3%)
#   adding: plots/bipartite_graphs/bipartite_topic_graph_Kohle_LD_K40_K50_topword_score.pdf (deflated 21%)
#   adding: plots/bipartite_graphs/cosine_similarity_matrix_runs_2155_2157.png (deflated 9%)
#   adding: plots/bipartite_graphs/cosine_similarity_graph_runs_2156_2157.pdf (deflated 26%)
#   adding: plots/bipartite_graphs/cosine_similarity_matrix_runs_2156_2157.png (deflated 8%)
#   adding: plots/bipartite_graphs/bipartite_topic_graph_Kohle_LD_K20_K30_topword_score.pdf (deflated 27%)
#   adding: plots/bipartite_graphs/.ipynb_checkpoints/ (stored 0%)
#   adding: plots/bipartite_graphs/bipartite_topic_graph_Kohle_NM_K40_stopword_['herr', 'jahr', 'mehr']_topword_score.pdf (deflated 27%)
#   adding: plots/bipartite_graphs/bipartite_topic_graph_Kohle_NM_K40_stopword_['herr', 'jahr', 'mehr']_topword_score.png (deflated 5%)
#   adding: plots/bipartite_graphs/bipartite_topic_graph_Kohle_NM_K20_K30_topword_score.pdf (deflated 29%)
#   adding: plots/bipartite_graphs/bipartite_topic_graph_Kohle_NM_K20_K30_topword_score.png (deflated 4%)
#   adding: plots/bipartite_graphs/bipartite_topic_graph_Kohle_NM_K40_K50_topword_score.png (deflated 4%)
#   adding: plots/bipartite_graphs/bipartite_topic_graph_Kohle_NM_K40_stopword_herr_topword_score.pdf (deflated 26%)
#   adding: plots/bipartite_graphs/bipartite_topic_graph_Kohle_NM_K40_K50_topword_score.pdf (deflated 26%)
#   adding: plots/bipartite_graphs/bipartite_topic_graph_Kohle_LD_K40_stopword_frequency_5_topword_score.pdf (deflated 26%)
#   adding: plots/bipartite_graphs/cosine_similarity_graph_runs_2155_2157.png (deflated 5%)
#   adding: plots/bipartite_graphs/bipartite_topic_graph_Kohle_NM_K30_K40_topword_score.png (deflated 4%)
#   adding: plots/bipartite_graphs/bipartite_topic_graph_Kohle_LD_K30_K40_topword_score.pdf (deflated 23%)
#   adding: plots/bipartite_graphs/bipartite_topic_graph_Kohle_LD_K40_stopword_['herr', 'jahr', 'mehr']_topword_score.pdf (deflated 22%)
#   adding: plots/bipartite_graphs/cosine_similarity_graph_runs_2155_2156.pdf (deflated 26%)
#   adding: plots/bipartite_graphs/bipartite_topic_graph_Kohle_LD_K40_stopword_mehr_topword_score.pdf (deflated 21%)
#   adding: plots/bipartite_graphs/bipartite_topic_graph_Kohle_NM_K40_stopword_mehr_topword_score.pdf (deflated 26%)
