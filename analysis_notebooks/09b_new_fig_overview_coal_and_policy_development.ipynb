# %%
import matplotlib.pylab as plt
import numpy as np
import pandas as pd
import time
import sys
import os

import seaborn as sns
import gensim

import django
import platform

if platform.node() == "srv-mcc-apsis":
    sys.path.append('/home/muef/tmv/BasicBrowser/')
else:
    # local paths
    sys.path.append('/media/Data/MCC/tmv/BasicBrowser')

os.environ.setdefault("DJANGO_SETTINGS_MODULE", "BasicBrowser.settings")
django.setup()

# import from appended path
import parliament.models as pm
from parliament.tasks import do_search, run_tm
import cities.models as cmodels
from django.contrib.auth.models import User
from tmv_app.models import *
from utils.tm_mgmt import update_topic_scores
from utils.text import *
from django.db.models import Q, Count, Func, F, Sum, Value, Case, When, IntegerField

# %% [markdown]
# ### importing data

# %%
# import coal data
data_dir = '../data/'
bk = pd.read_csv(data_dir + 'Braunkohlefoerderung.csv', header=1, index_col=0)
sk = pd.read_csv(data_dir + 'Steinkohlefoerderung.csv', header=1, index_col=0)
si = pd.read_csv(data_dir + 'hard coal imports.csv', header=1, index_col=0)

coal_production = pd.merge(bk, sk, left_index=True, right_index=True, how='outer')
# convert from 1000 t to Mt
coal_production = coal_production / 1000
coal_production = pd.merge(coal_production, si, left_index=True, right_index=True, how='outer')

coal_production.interpolate().plot.area(linewidth=0)
#coal_production.interpolate().plot(linewidth=2)
plt.ylabel('production/import [Mt]')
# Out:
# Text(0, 0.5, 'production/import [Mt]')

# %%
# import classification
run_id = 2350

topic_dir = "../plots/topic_analysis_{}/".format(run_id)
topic_classification = pd.read_csv(topic_dir + '0_topic_list_run{}_labeled.csv'.format(run_id), index_col=0)
topic_classification #['classification']
# Out:
#                                    label                label short  \
# 184089                      common terms               common terms
# 184090                        procedural                 procedural
# 184081                   economic policy            economic policy
# 184105                federal government         federal government
# 184102                 policy statements          policy statements
# 184106                            budget                     budget
# 184086   European Coal & Steel Community                       ECSC
# 184098         international cooperation  international cooperation
# 184108                 energy supply mix          energy supply mix
# 184097                      procedural 2               procedural 2
# 184104                          budget 2                   budget 2
# 184096                        job market                 job market
# 184094                     fiscal reform              fiscal reform
# 184095  energy transition & power market          energy transition
# 184113              coal policy & prices                coal policy
# 184111                climate protection         climate protection
# 184109                 economic policy 2          economic policy 2
# 184080          debate government policy          government policy
# 184107         housing & social security                    housing
# 184110   economic policy & participation              participation
# 184103                    foreign policy             foreign policy
# 184100             hard coal & subsidies                  hard coal
# 184092                  transport policy           transport policy
# 184087                 subsidy reduction          subsidy reduction
# 184112                        tax policy                 tax policy
# 184091            research & development                   research
# 184093           risks of nuclear energy              nuclear risks
# 184088                 nuclear phase-out          nuclear phase-out
# 184084                     reunification              reunification
# 184085                       coal mining                coal mining
# 184079          environmental protection   environmental protection
# 184101             structural adjustment      structural adjustment
# 184082               agricultural policy        agricultural policy
# 184083                    green policies             green policies
# 184099                 natural resources          natural resources
#
#                          classification                     label Finn  \
# 184089  procedural and general politics                      stopwords
# 184090  procedural and general politics                     procedural
# 184081               economy and budget                economic policy
# 184105  procedural and general politics                   procedural 2
# 184102  procedural and general politics              economic system ?
# 184106               economy and budget                         budget
# 184086       international and regional  German-French economic policy
# 184098       international and regional                         Europe
# 184108                           energy                  energy policy
# 184097  procedural and general politics                        Mixed ?
# 184104               economy and budget                       budget 2
# 184096               economy and budget                     job market
# 184094               economy and budget                        Mixed ?
# 184095                           energy                   power market
# 184113                           energy                    coal prices
# 184111                      environment                 climate policy
# 184109               economy and budget              economic policy 2
# 184080  procedural and general politics         debate with opposition
# 184107               economy and budget                        housing
# 184110               economy and budget              economic policy 3
# 184103       international and regional                 foreign policy
# 184100                           energy        coal industry subsidies
# 184092                           energy                      transport
# 184087               economy and budget              subsidy reduction
# 184112               economy and budget                     tax policy
# 184091               economy and budget                          R & D
# 184093                           energy                 nuclear energy
# 184088                           energy               nuclear energy 2
# 184084       international and regional                            GDR
# 184085                           energy                    coal mining
# 184079                      environment         environment protection
# 184101       international and regional          structural adjustment
# 184082                      environment                    agriculture
# 184083                      environment          ecological tax reform
# 184099                      environment              natural resources
#
#                                Discussion with Jan  \
# 184089                                         NaN
# 184090                                         NaN
# 184081                                         NaN
# 184105                                         NaN
# 184102                                         NaN
# 184106                                         NaN
# 184086                                         NaN
# 184098                               international
# 184108                                         NaN
# 184097                               Gesetzgebung?
# 184104                                Periode 5-12
# 184096                                         NaN
# 184094                       Haushalt Steuerreform
# 184095  Energiewende + Auswirkungen auf Strommarkt
# 184113                                         NaN
# 184111                                         NaN
# 184109                                         NaN
# 184080           Debatte Regierungspolitik Merkel
# 184107                     Sozial + Wohnunspolitik
# 184110          Mitbestimmung + Wirtschaftspolitik
# 184103                                         NaN
# 184100                                         NaN
# 184092                                         NaN
# 184087                                         NaN
# 184112                                         NaN
# 184091                                         NaN
# 184093                       Kernenergie + Risiken
# 184088                                Atomausstieg
# 184084                           Wiedervereinigung
# 184085                                         NaN
# 184079                                         NaN
# 184101                                         NaN
# 184082                                Agrarpolitik
# 184083                          Politik der Grünen
# 184099                       Umwelt und Ressourcen
#
#                                                       Jan  \
# 184089                                         stop words
# 184090                                         procedural
# 184081                   Wirtschaftspolitik/ -entwicklung
# 184105                                    Bundesregierung
# 184102                                                NaN
# 184106                   Haushaltspolitik/ Bundeshaushalt
# 184086             Europäische (Wirtschafts-)gemeinschaft
# 184098                             Internationale Politik
# 184108                                     Energiepolitik
# 184097                                       Gesetzgebung
# 184104          Bundeshaushalt - Schulden & Investitionen
# 184096                    Arbeitsmarkt & Arbeitslosigkeit
# 184094                                  Haushalt & Steuer
# 184095              Energiewende & Strommakrtauswirkungen
# 184113                            Kohlepolitk/ Kohlepreis
# 184111                                        Klimaschutz
# 184109                                 Wirtschaftspolitik
# 184080  Merkel Regierungspolitik?: Debatte Regierungsp...
# 184107                                 Soziales & Wohnung
# 184110                Wirtschaftspolitik & Mitbestimmung?
# 184103                                       Außenpolitik
# 184100                                         Steinkohle
# 184092                             Bahn & Verkehrspolitik
# 184087                                   Subventionsabbau
# 184112                                      Steuerpolitik
# 184091                    Forschungs- und Bildungspolitik
# 184093                       Kernenergie und ihre Risiken
# 184088                                        Atomaustieg
# 184084                                  Wiedervereinigung
# 184085                                       Kohlebergbau
# 184079                               Umwelt & Naturschutz
# 184101                    Strukturwandel/ Strukturpolitik
# 184082                                       Agrarpolitik
# 184083                 Umweltpolitik & Risikotechnologien
# 184099                                Umwelt & Ressourcen
#
#                                                     Jan.1  \
# 184089                                                NaN
# 184090                                                NaN
# 184081                                                NaN
# 184105                                          Procedere
# 184102                                     Grundsatzreden
# 184106                                                NaN
# 184086     Deutsch-französische Wirtschaftszusammenarbeit
# 184098                                 Europäische Politk
# 184108        look at topic score development and explain
# 184097                                    EWG highlighted
# 184104                                                NaN
# 184096                                                NaN
# 184094                                                NaN
# 184095                                                NaN
# 184113                                                NaN
# 184111                                                NaN
# 184109                                                NaN
# 184080                                                NaN
# 184107                                                NaN
# 184110                                                NaN
# 184103                                                NaN
# 184100  auch in letzter Periode sind die keywords richtig
# 184092                                                NaN
# 184087                                                NaN
# 184112                                                NaN
# 184091                                                NaN
# 184093                                                NaN
# 184088                                                NaN
# 184084                                                NaN
# 184085                                                NaN
# 184079                                                NaN
# 184101                                                NaN
# 184082                                                NaN
# 184083                                      Grüne Politik
# 184099                                                NaN
#
#                         Jan period  \
# 184089                         NaN
# 184090                         NaN
# 184081                         NaN
# 184105                         NaN
# 184102                         NaN
# 184106  1 bis 5/6 - hält sich aber
# 184086                         NaN
# 184098                         NaN
# 184108                         NaN
# 184097                         NaN
# 184104              fünf bis zwölf
# 184096                         NaN
# 184094                  elf bis 15
# 184095                         NaN
# 184113                         NaN
# 184111                         NaN
# 184109                         NaN
# 184080                         NaN
# 184107                         NaN
# 184110                         NaN
# 184103                         NaN
# 184100                         NaN
# 184092                         NaN
# 184087                         NaN
# 184112                         NaN
# 184091                         NaN
# 184093                         NaN
# 184088                         NaN
# 184084                         NaN
# 184085                         NaN
# 184079                         NaN
# 184101                         NaN
# 184082                         NaN
# 184083                         NaN
# 184099                         NaN
#
#                                        top words weighted  \
# 184089  tun, wirklich, wiss, red, gar, darub, natur, r...
# 184090  darauf, haus, darub, darf, bereich, punkt, bun...
# 184081  wirtschaft, unternehm, entwickl, deutsch, mark...
# 184105  bundeskanzl, partei, regier, deutsch, sozialde...
# 184102  deutsch, volk, bundesregier, freiheit, wirtsch...
# 184106  milliard, million, bund, haushalt, hoh, rund, ...
# 184086  europa, deutsch, vertrag, franzos, frankreich,...
# 184098  europa, gemeinsam, international, deutschland,...
# 184108  energi, erneuerbar, energiepolit, kohl, bundes...
# 184097  gesetz, wirtschaft, bundesregier, entwurf, bun...
# 184104  haushalt, milliard, bundesfinanzminist, invest...
# 184096  arbeit, arbeitslos, arbeitsplatz, sozial, arbe...
# 184094  spd, prozent, deutschland, euro, koalition, st...
# 184095  strom, energi, erneuerbar, wettbewerb, prozent...
# 184113  million, tonn, kohl, bundeswirtschaftsminist, ...
# 184111  klimaschutz, prozent, deutschland, ziel, emiss...
# 184109  wachstum, wirtschaft, bundesregier, wirtschaft...
# 184080  endlich, kolleginn, regier, generation, merkel...
# 184107  sozial, gesetz, wohnung, wohnungsbau, rent, ho...
# 184110  gesetz, unternehm, gesetzentwurf, entwurf, bet...
# 184103  deutsch, deutschland, staat, bundesrepubl, mil...
# 184100  steinkohl, deutsch, bundesregier, saar, kohl, ...
# 184092  bundesbahn, deutsch, verkehr, strass, bahn, ve...
# 184087  euro, subvention, milliard, prozent, mittelsta...
# 184112  steu, belast, kommun, erhoh, hoh, gemeind, ent...
# 184091  forschung, million, bereich, haushalt, mittel,...
# 184093  kernenergi, kernkraftwerk, technik, anlag, tec...
# 184088  kernenergi, energiepolit, deutschland, grun, k...
# 184084  berlin, ddr, bundesland, ost, ostdeutsch, west...
# 184085  bergbau, bundesregier, bergleut, steinkohlenbe...
# 184079  umweltschutz, umweltpolit, umwelt, bundesregie...
# 184101  nordrheinwestfal, region, bundesregier, gebiet...
# 184082  landwirtschaft, bau, betrieb, deutsch, agrarpo...
# 184083  okolog, grun, bundesregier, atomenergi, okoste...
# 184099  rohstoff, wald, schutz, natur, umwelt, beispie...
#
#                                             top words avg  \
# 184089  tun, wiss, wirklich, red, gar, darub, natur, r...
# 184090  darauf, darub, haus, bereich, punkt, debatt, b...
# 184081  unternehm, wirtschaft, deutsch, deutschland, m...
# 184105  bundeskanzl, deutsch, partei, deutschland, reg...
# 184102  deutsch, volk, bundesregier, freiheit, deutsch...
# 184106  milliard, bund, million, hoh, rund, haushalt, ...
# 184086  europa, union, gemeinschaft, deutsch, vertrag,...
# 184098  europa, gemeinsam, international, staat, gemei...
# 184108  energi, erneuerbar, kohl, energiepolit, energi...
# 184097  gesetz, wirtschaft, bundesregier, entwurf, bun...
# 184104  haushalt, bundesfinanzminist, milliard, invest...
# 184096  arbeit, arbeitslos, sozial, arbeitnehm, arbeit...
# 184094  spd, prozent, koalition, euro, deutschland, st...
# 184095  wettbewerb, strom, kost, kraftwerk, preis, str...
# 184113  million, tonn, staatssekretar, kohl, pro, deut...
# 184111  prozent, klimaschutz, coemission, ziel, deutsc...
# 184109  wachstum, wirtschaft, wirtschaftspolit, bundes...
# 184080  generation, schul, endlich, regier, kolleginn,...
# 184107  sozial, wohnung, rent, gesetz, miet, wohnungsb...
# 184110  gesetz, gesetzentwurf, unternehm, entwurf, mit...
# 184103  deutsch, deutschland, staat, bundesregier, rus...
# 184100  saar, saarland, steinkohl, deutsch, bundesregi...
# 184092  deutsch, bahn, bundesbahn, strass, verkehrspol...
# 184087  subvention, handwerk, euro, mittelstand, milli...
# 184112  steu, kommun, belast, burg, entlast, hoh, erho...
# 184091  forschung, wissenschaft, million, bereich, hau...
# 184093  kernenergi, kernkraftwerk, technisch, anlag, t...
# 184088  kernenergi, energiepolit, grun, deutschland, m...
# 184084  berlin, ddr, ost, bundesland, west, ostdeutsch...
# 184085  bergbau, bergleut, bundesregier, steinkohlenbe...
# 184079  umweltschutz, umweltpolit, umwelt, luft, bunde...
# 184101  nordrheinwestfal, gebiet, region, bund, bundes...
# 184082  landwirtschaft, bau, landlich, raum, landwirt,...
# 184083  atomenergi, grun, okolog, bundesregier, topf, ...
# 184099  rohstoff, wald, schad, schutz, natur, umwelt, ...
#
#                                            top words peak  score pct  \
# 184089  ding, vielleicht, wirklich, gar, wiss, seh, we...  10.672064
# 184090  haus, darauf, darf, darub, entscheid, lass, bu...   9.348242
# 184081  wirtschaft, entwickl, bereich, wirtschaftspoli...   5.492435
# 184105  regier, bundeskanzl, volk, partei, sozialdemok...   4.037749
# 184102  deutsch, deutschland, gemeinsam, wirtschaft, f...   3.989937
# 184106  million, milliard, bund, haushalt, hoh, bundes...   3.783282
# 184086  deutsch, schumanplan, deutschland, vertrag, fr...   3.685528
# 184098  deutschland, wichtig, international, gemeinsam...   3.627137
# 184108  energiepolit, bundesregier, energi, kohl, kern...   3.422472
# 184097  ewg, rechtzeit, gesetz, endgult, wirtschaft, b...   3.160606
# 184104  milliard, haushalt, stoltenberg, finanzpolit, ...   2.868956
# 184096  arbeitslos, arbeitsplatz, sozial, arbeitnehm, ...   2.834880
# 184094  spd, prozent, deutschland, steu, koalition, ha...   2.748934
# 184095  energi, erneuerbar, strom, energiew, prozent, ...   2.726639
# 184113  kohl, deutsch, million, tonn, preis, hoh, bund...   2.593373
# 184111  klimaschutz, prozent, emissionshandel, deutsch...   2.501910
# 184109  bundesregier, wirtschaft, offent, wirtschaftsp...   2.166607
# 184080  endlich, kolleginn, deutschland, zukunft, merk...   2.116442
# 184107  gesetz, wohnungsbau, wohnung, mittel, hand, ho...   2.090893
# 184110  gesetz, betrieb, unternehm, gewerkschaft, wirt...   2.074873
# 184103  deutschland, deutsch, west, ost, bundesrepubl,...   2.053774
# 184100  kohl, bundesregier, deutsch, steinkohl, jahrhu...   1.952662
# 184092  bundesbahn, deutsch, verkehr, strass, bundesre...   1.904648
# 184087  euro, prozent, milliard, subvention, deutschla...   1.853460
# 184112  steu, gesetz, erhoh, belast, einkomm, umsatzst...   1.780998
# 184091  haushalt, forschung, million, bereich, mittel,...   1.770372
# 184093  kernenergi, kernkraftwerk, technisch, bundesre...   1.672956
# 184088  kernenergi, energiepolit, bundesregier, minist...   1.562572
# 184084  bundesland, ost, ddr, ostdeutsch, west, berlin...   1.495431
# 184085  bundesregier, bergbau, deutsch, energiepolit, ...   1.447272
# 184079  umweltschutz, bundesregier, umweltpolit, umwel...   1.403016
# 184101  nordrheinwestfal, region, bundesregier, bund, ...   1.340225
# 184082  landwirtschaft, betrieb, deutsch, grun, preis,...   1.294024
# 184083  okolog, okosteu, bundesregier, grun, umweltpol...   1.278078
# 184099  rohstoff, bergrecht, wald, schutz, okolog, deu...   1.247556
#
#                 score
# 184089  419821.116446
# 184090  367744.157874
# 184081  216063.202495
# 184105  158838.262969
# 184102  156957.446933
# 184106  148827.974002
# 184086  144982.504003
# 184098  142685.511866
# 184108  134634.299691
# 184097  124332.949316
# 184104  112859.939034
# 184096  111519.416483
# 184094  108138.441150
# 184095  107261.414586
# 184113  102018.940770
# 184111   98420.932013
# 184109   85230.677601
# 184080   83257.269048
# 184107   82252.210242
# 184110   81622.046418
# 184103   80792.015477
# 184100   76814.440919
# 184092   74925.650338
# 184087   72912.023838
# 184112   70061.484686
# 184091   69643.469940
# 184093   65811.290700
# 184088   61468.947410
# 184084   58827.731138
# 184085   56933.258894
# 184079   55192.283772
# 184101   52722.206164
# 184082   50904.719175
# 184083   50277.434636
# 184099   49076.779971

# %% [markdown]
# # show in plot:
#
# - aggregated topic scores
# - number of speeches
# - coal production
# - governments (with color)
# - policy events

# %%
run_id = 2350

save_dir = "../plots/topic_analysis_{}".format(run_id)
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)

dts = DocTopic.objects.filter(run_id=run_id)
# total score of all DocTopics
print(dts.aggregate(
    n = Sum('score')
))
dts.values('topic__title','ut__document__parlperiod__n').annotate(n = Sum('score'))
topic_period_scores = dts.values('topic__title','topic__id', 'ut__document__parlperiod__n').annotate(score = Sum('score'))

df = pd.DataFrame.from_dict(topic_period_scores)
df["classification"] = df["topic__id"]
def id_to_class(idn):
    return topic_classification.loc[idn]['classification']
df["classification"] = df["classification"].apply(id_to_class)

dfagg = df.groupby(["classification","ut__document__parlperiod__n"]).sum().drop(columns=["topic__id"])

dfagg = dfagg.unstack().transpose().droplevel(0)
# Out:
# {'n': 3933832.4500019867}

# %%
party_color_map = {'spd': "#0088FF", 'cducsu': "#222222", 'fdp': "#FFED00",
                   'gruene': "#64A12D", 'linke': "#8C3473", 'spd': "#EB001F", 'dp': '#808080'}

gvmt = pd.read_csv(data_dir + 'List of German governments.csv', header=1)

def plot_government(ax, triangle=False, ylabel_pad=None, x_pad=0.2, y_pad=0.05):
    from matplotlib.patches import Rectangle, Polygon

    for i in gvmt.index:
        if triangle:
            xy = np.array([[gvmt.loc[i]['begin year'], 1],
                      [gvmt.loc[i]['end year'], 1],
                      [gvmt.loc[i]['begin year'], 0]])
            rect = Polygon(xy, alpha=0.8,
                             edgecolor='k', linewidth=0, facecolor = party_color_map[gvmt.loc[i]['Party 1']]) 
            ax.add_patch(rect)
            xy = np.array([[gvmt.loc[i]['begin year'], 0],
                      [gvmt.loc[i]['end year'], 1],
                      [gvmt.loc[i]['end year'], 0]])
            rect = Polygon(xy, alpha=0.8,
                             edgecolor='k', linewidth=0, facecolor = party_color_map[gvmt.loc[i]['Party 2']]) 
            ax.add_patch(rect)

        else:
            width = gvmt.loc[i]['end year'] - gvmt.loc[i]['begin year'] - 2*x_pad
            height = 0.5 - 2 * y_pad
            pos = gvmt.loc[i]['begin year'] + x_pad
            rect = Rectangle((pos, 0.5 + y_pad), width, height, alpha=0.8,
                             edgecolor='k', linewidth=0, facecolor = party_color_map[gvmt.loc[i]['Party 1']]) 
            ax.add_patch(rect)
            rect = Rectangle((pos, y_pad), width, height, alpha=0.8,
                             edgecolor='k', linewidth=0, facecolor = party_color_map[gvmt.loc[i]['Party 2']]) 
            ax.add_patch(rect)
    
    ax.set_xlim([1948.9, 2019.1])
    ax.set_yticks([])
    ax.grid(False)
    ax.set_ylabel('government\n coalitions', labelpad=ylabel_pad)
    
ax = plt.subplot(111)
plot_government(ax)

# %%
mid_years = np.array([1951. , 1955. , 1959. , 1963. , 1967, 1970.5,
                      1974  , 1978. , 1981.5 , 1985. , 1988.5, 1992. ,
                      1996. , 2000. , 2003.5, 2007. , 2011. , 2015. , 2018. ])

# %%
# load event table:
filename = "../datasets/Policy events coal.csv"
polevents = pd.read_csv(filename, header=1).fillna("")
polevents
# Out:
#     year  period                                       policy event  \
# 0   1951       1  Creation of the European Coal and Steel Community
# 1   1957       3                        European Economic Community
# 2   1965       5  Law to ensure German hard coal use in power ge...
# 3   1971       6                        First environmental program
# 4   1974       7                     Introduction of “Kohlepfennig”
# 5   1974       7                              Pollution control law
# 6   1980       9                                 Jahrhundertvertrag
# 7   1983      10                 Entry of green party in parliament
# 8   1986      10                         Chernobyl nuclear disaster
# 9   1986      10     Creation of the federal environmental ministry
# 10  1990      10                               German reunification
# 11  1992      12                                     Rio Conference
# 12  1994      12                                             UNFCCC
# 13  1997      13                         Hard coal mining subsidies
# 14  1997      13                                     Kyoto protocol
# 15  2000      14                                                EEG
# 16  2000      14                      Decision on nuclear phase-out
# 17  1999      14                                            Eco tax
# 18  2005      15                                             EU ETS
# 19  2007      16                        Hard coal subsidy phase-out
# 20  2011      17                         Fukushima nuclear disaster
# 21  2011      17                                    Atom-Moratorium
# 22  2015      18                                    Paris agreement
# 23  2016      18                                Climate action plan
# 24  2019      19                                    Coal commission
#
#                        short label  \
# 0             Creation of the ECSC
# 1      European Economic Community
# 2            1. Verstromungsgesetz
# 3      First environmental program
# 4                     Kohlepfennig
# 5            Pollution control law
# 6               Jahrhundertvertrag
# 7    Green party enters parliament
# 8       Chernobyl nuclear disaster
# 9   Federal environmental ministry
# 10            German reunification
# 11                  Rio Conference
# 12                          UNFCCC
# 13      Hard coal mining subsidies
# 14                  Kyoto protocol
# 15                             EEG
# 16      Nuclear phase-out decision
# 17                         Eco tax
# 18                          EU ETS
# 19          Coal subsidy phase-out
# 20                       Fukushima
# 21                 Atom-Moratorium
# 22                 Paris agreement
# 23             Climate action plan
# 24                 Coal commission
#
#                              explanation, legislation         type of event  \
# 0                                                      international treaty
# 1                                                      international treaty
# 2                               1. Verstromungsgesetz           legislation
# 3                                      Umweltprogramm     government policy
# 4   extra charge on electricity for coal mined Ger...           legislation
# 5                       Bundes-Immissionsschutzgesetz           legislation
# 6   treaty between electricity utilities and minin...     government policy
# 7                                                       parliamentary event
# 8                                                       international event
# 9                                                         government policy
# 10                                                           national event
# 11                                                      international event
# 12  United Nations Framework Convention on Climate...  international treaty
# 13     Steinkohlebeihilfengesetz, hard coal subsidies           legislation
# 14                                                     international treaty
# 15  Erneuerbare-Energien-Gesetz implementing renew...           legislation
# 16                         Atomausstiegsgesetz (2002)           legislation
# 17  Gesetz zum Einstieg in die ökologische Steuerr...           legislation
# 18                  European Emissions Trading Scheme        EU legislation
# 19                      Steinkohlefinanzierungsgesetz           legislation
# 20                                                      international event
# 21  Withdrawal of  the extension of the run-time o...           legislation
# 22                                                     international treaty
# 23  National strategy to meet the targets of the P...     government policy
# 24  Kommission für Wachstum, Strukturwandel und Be...     government policy
#
#             scope
# 0   international
# 1   international
# 2        national
# 3        national
# 4        national
# 5        national
# 6        national
# 7        national
# 8   international
# 9        national
# 10       national
# 11  international
# 12  international
# 13       national
# 14  international
# 15       national
# 16       national
# 17       national
# 18  international
# 19       national
# 20  international
# 21  international
# 22  international
# 23       national
# 24       national

# %%
concat_polevents = polevents.groupby('year')['short label'].apply(', '.join)
concat_polevents[2000] = "Eco tax, EEG, Nuclear phase-out decision"
concat_polevents = concat_polevents.drop(1999)
concat_polevents
# Out:
# year
# 1951                                 Creation of the ECSC
# 1957                          European Economic Community
# 1965                                1. Verstromungsgesetz
# 1971                          First environmental program
# 1974                  Kohlepfennig, Pollution control law
# 1980                                   Jahrhundertvertrag
# 1983                        Green party enters parliament
# 1986    Chernobyl nuclear disaster, Federal environmen...
# 1990                                 German reunification
# 1992                                       Rio Conference
# 1994                                               UNFCCC
# 1997           Hard coal mining subsidies, Kyoto protocol
# 2000             Eco tax, EEG, Nuclear phase-out decision
# 2005                                               EU ETS
# 2007                               Coal subsidy phase-out
# 2011                           Fukushima, Atom-Moratorium
# 2015                                      Paris agreement
# 2016                                  Climate action plan
# 2019                                      Coal commission
# Name: short label, dtype: object

# %%
interpolate = True
events = False

if interpolate:
    from scipy.interpolate import PchipInterpolator
    x_years = np.arange(1949, 2019, 0.1)
    
from matplotlib.patches import ConnectionPatch, Patch
import matplotlib.lines
import textwrap

sns.set_context("talk")
sns.set_style("ticks")
sns.set_style({'axes.spines.bottom': True,
               'axes.grid':True,
               'axes.spines.left': False,
               'axes.spines.right': False,
               'axes.spines.top': False,
               'ytick.left': False,
               'figure.facecolor':'w'})

sns.set_palette('husl', 5)
colors = sns.color_palette()
sns.set_palette(list(reversed(colors[:4])))

fig, ax = plt.subplots(nrows=3, ncols=1, sharex=True, figsize=(10, 10),
                       gridspec_kw={'height_ratios': [5, 2, 0.5]})

# set up values for figure scaling
dfs = dfagg[["economy and budget", "energy", "environment",
             "international and regional"]]
max_val = 1.5 * dfs.max().max()
y_max = len(dfs.columns)*max_val

# draw events
# =================================================================
# draw lines across multiple subplots:
# https://stackoverflow.com/questions/17543359/drawing-lines-between-two-plots-in-matplotlib
#lines = []

#for year in np.arange(1950,2020, 10):
        
    #option 1:
    #con = ConnectionPatch(xyA=[year, y_max], xyB=[year, 0], coordsA="data", coordsB="data",
    #                      axesA=ax[0], axesB=ax[2], color='gray', zorder=200)
    #ax[0].add_artist(con)

    #option 2:
    #transFigure = fig.transFigure.inverted()

    #coord1 = transFigure.transform(ax[0].transData.transform([year, y_max]))
    #coord2 = transFigure.transform(ax[2].transData.transform([year, 0]))

    #lines.append(matplotlib.lines.Line2D((coord1[0],coord2[0]),(coord1[1],coord2[1]),
    #                           transform=fig.transFigure, color='k', linewidth=1))

#fig.lines = lines
# =================================================================

# plot coal production
coal_production.interpolate().plot(linewidth=2, ax=ax[1], color=['brown', 'k', 'b'])
ax[1].set_ylabel('production,\nimport [Mt]')
ax[1].set_ylim([-90,490])
ax[1].legend(frameon=True, framealpha=1)

gov_parties = ['cducsu', 'fdp', 'spd', 'gruene']
legend_elements = [Patch(facecolor=party_color_map[party], label=party) for party in gov_parties]#edgecolor='r',
ax[2].legend(handles=legend_elements, loc='center', bbox_to_anchor=(1.1, 1.0), frameon=True)

# plot government coalitions
plot_government(ax[2], ylabel_pad=43)

# plot policy events
if events:
    for index in concat_polevents.index:
        year = index
        text = "\n ".join(textwrap.wrap(concat_polevents[year], 30))

        ax[0].vlines(year, ymin=-max_val, ymax=y_max, linewidth=1, zorder=0)
        if concat_polevents[year] in ["Climate action plan", "Eco tax, EEG, Nuclear phase-out decision"]:
            year = year + 1

        ax[0].text(year - 0.3, y_max, text, ha="left", va="bottom", rotation=45, size=10)

# plot aggregate topics
#ax[0].set_yticks(np.arange(0, y_max, max_val))
ax[0].set_yticks([])

for i, t in enumerate(reversed(dfs.columns)):
    if interpolate:
        interp_func = PchipInterpolator(mid_years, dfs[t])

        ax[0].fill_between(x_years, interp_func(x_years) + i*max_val, i*max_val - interp_func(x_years), label=t)
    else:
        ax[0].fill_between(mid_years, dfs[t] + i*max_val, i*max_val - dfs[t], label=t)
    ax[0].text(2019.7, (i+0.) *max_val, textwrap.fill(t, 16), fontsize=12)

ax[0].set_xlabel('year')
ax[0].set_ylabel('aggregated topic scores', labelpad=43)
ax[0].set_ylim([-max_val, y_max])
ax[0].set_xticks([1950, 1960, 1970, 1980, 1990, 2000, 2010, 2019])

#ax[1].patch.set_facecolor('none')
ax[0].set_zorder(2)
plt.subplots_adjust(hspace=.0)

plt.savefig(os.path.join(save_dir, 'topic_evolution_run{}_aggregate.png'.format(run_id)),
            dpi=150, bbox_inches="tight", facecolor=fig.get_facecolor())
