# %%
import matplotlib.pyplot as plt
import re
# import networkx as nx
import numpy as np
import pandas as pd
import time
import sys
import os
import datetime

# preamble for jupyter notebook and django
import django
import platform
from django.db.models import Q, F, Sum, Count, FloatField, Case, When

if platform.node() == "mcc-apsis":
    sys.path.append('/home/galm/software/django/tmv/BasicBrowser/')
else:
    # local paths
    sys.path.append('/media/Data/MCC/tmv/BasicBrowser/')

os.environ.setdefault("DJANGO_SETTINGS_MODULE", "BasicBrowser.settings")
django.setup()

from parliament.models import *
from scoping.models import *

# %%
p = Project.objects.get(pk=134)
dos = DocOwnership.objects.filter(tag__query__project=p)

utids = dos.values_list("utterance__id",flat=True)

# %%
pars = Paragraph.objects.filter(utterance__in=utids)
rekohle = "(\w*(?:K|k)ohle\w+)"
kps = pars.filter(text__iregex=rekohle)

kohle_compounds = set()
for kp in kps:
    for x in re.findall(rekohle,kp.text):
        kohle_compounds.add(x.lower())
        
print(len(kohle_compounds))
        
kohle_compounds
# Out:
# 446
# {'ballastkohlesorten',
#  'braunkohleabbau',
#  'braunkohleanteil',
#  'braunkohleausschusses',
#  'braunkohlebergbau',
#  'braunkohlebergbaus',
#  'braunkohleeinsatz',
#  'braunkohleförderung',
#  'braunkohlegebiet',
#  'braunkohlegebiete',
#  'braunkohlegegnern',
#  'braunkohlegroßkraftwerke',
#  'braunkohleindustrie',
#  'braunkohlekapazitäten',
#  'braunkohlekraftwerk',
#  'braunkohlekraftwerke',
#  'braunkohlekraftwerken',
#  'braunkohlemeiler',
#  'braunkohlenbergbau',
#  'braunkohlenbergbaus',
#  'braunkohlenbergwerk',
#  'braunkohlenbriketts',
#  'braunkohlengewinnung',
#  'braunkohlenkraftwerke',
#  'braunkohlenplanverfahren',
#  'braunkohlenrevier',
#  'braunkohlentagebau',
#  'braunkohlentagebaue',
#  'braunkohlenwerke',
#  'braunkohlepfennig',
#  'braunkohlepolitik',
#  'braunkohleprivilegierung',
#  'braunkohleregionen',
#  'braunkohlereserve',
#  'braunkohlerestseen',
#  'braunkohlerevier',
#  'braunkohlereviere',
#  'braunkohlerevieren',
#  'braunkohleruinen',
#  'braunkohlesanierung',
#  'braunkohlesanierungsgesellschaften',
#  'braunkohlestrom',
#  'braunkohletagebau',
#  'braunkohletagebaue',
#  'braunkohletagebauen',
#  'braunkohleunternehmen',
#  'braunkohleveredelung',
#  'braunkohleveredlung',
#  'braunkohleverschwelung',
#  'braunkohleverstromung',
#  'braunkohleverstromungsgesetz',
#  'braunkohlewende',
#  'braunkohlewerke',
#  'chlorkohlenwasserstoffhaltigen',
#  'esskohlennüsse',
#  'fluorchlorkohlenwasserstoffe',
#  'fluorchlorkohlenwasserstoffen',
#  'hausbrandkohlen',
#  'importkohlekontingents',
#  'importkohlenkontingente',
#  'kohleabbau',
#  'kohleabgabe',
#  'kohleabnahmegarantie',
#  'kohleabsatz',
#  'kohleabsatzes',
#  'kohleanpassungsgesetzes',
#  'kohleanteil',
#  'kohleanteile',
#  'kohlearbeiter',
#  'kohlearten',
#  'kohleaus',
#  'kohleausstieg',
#  'kohleausstiegsdebatte',
#  'kohleausstiegsgesetz',
#  'kohlebaggern',
#  'kohlebasis',
#  'kohlebeauftragte',
#  'kohlebeauftragten',
#  'kohlebeauftragter',
#  'kohlebefeuerten',
#  'kohlebeihilfe',
#  'kohlebeihilfen',
#  'kohlebereich',
#  'kohlebergbau',
#  'kohlebergbaues',
#  'kohlebergbaus',
#  'kohlebezugsverträge',
#  'kohleblöcken',
#  'kohleboom',
#  'kohlechemie',
#  'kohledebatte',
#  'kohleeinfuhr',
#  'kohleeinheitsgesellschaft',
#  'kohleeinsatz',
#  'kohleexporte',
#  'kohlefans',
#  'kohlefaserverbundstofftechnologie',
#  'kohlefinanzierung',
#  'kohleflözgesteinen',
#  'kohleforschung',
#  'kohlefrachthilfe',
#  'kohlefrage',
#  'kohlefriede',
#  'kohleförderung',
#  'kohlegebiet',
#  'kohlegebunden',
#  'kohlegefeuerte',
#  'kohlegefeuerten',
#  'kohlegesellschaften',
#  'kohlegesetz',
#  'kohlegespräch',
#  'kohlehandels',
#  'kohleheizkraftwerk',
#  'kohlehilfe',
#  'kohlehilfen',
#  'kohlehydrate',
#  'kohleimport',
#  'kohleimporten',
#  'kohleimporteuren',
#  'kohleimportregelung',
#  'kohleimports',
#  'kohleindustrie',
#  'kohlekalamität',
#  'kohlekartell',
#  'kohlekeller',
#  'kohlekommissar',
#  'kohlekompromiss',
#  'kohlekompromisses',
#  'kohlekompromiß',
#  'kohlekontingent',
#  'kohlekonzerne',
#  'kohlekonzernen',
#  'kohlekraft',
#  'kohlekraftanlagen',
#  'kohlekrafterke',
#  'kohlekrafterken',
#  'kohlekraftwerk',
#  'kohlekraftwerke',
#  'kohlekraftwerken',
#  'kohlekraftwerkes',
#  'kohlekraftwerks',
#  'kohlekraftwerkspark',
#  'kohlekreises',
#  'kohlekrise',
#  'kohlekumpel',
#  'kohlelager',
#  'kohlelasten',
#  'kohleleistung',
#  'kohlelokomotiven',
#  'kohleländer',
#  'kohlemangels',
#  'kohlemeiler',
#  'kohlemenge',
#  'kohlen',
#  'kohlenabgabe',
#  'kohlenabnehmerländern',
#  'kohlenabsatzkrise',
#  'kohlenanordnung',
#  'kohlenarten',
#  'kohlenausfuhr',
#  'kohlenausfuhrland',
#  'kohlenbedarf',
#  'kohlenbehörde',
#  'kohlenberg',
#  'kohlenbergbau',
#  'kohlenbergbaues',
#  'kohlenbergbaugebiet',
#  'kohlenbergbauleitung',
#  'kohlenbergbaus',
#  'kohlenbergwerken',
#  'kohlenbestände',
#  'kohlenbewirtschaftung',
#  'kohlendebatte',
#  'kohlendebatten',
#  'kohlendioxid',
#  'kohlendioxidanstiegs',
#  'kohlendioxidausstoß',
#  'kohlendioxidausstoßes',
#  'kohlendioxidbilanz',
#  'kohlendioxideintrag',
#  'kohlendioxidemissionen',
#  'kohlendioxidgehalt',
#  'kohlendioxidkonzentration',
#  'kohlendioxidkreislaufs',
#  'kohlendioxidproduktion',
#  'kohlendioxidspeicher',
#  'kohlendioxidumfangs',
#  'kohlendioxyd',
#  'kohleneinfuhr',
#  'kohleneinfuhrdispositionen',
#  'kohleneinfuhren',
#  'kohleneinfuhrkontrakte',
#  'kohleneinfuhrpolitik',
#  'kohleneinfuhrstopp',
#  'kohleneinfuhrverträge',
#  'kohleneinfuhrverträgen',
#  'kohleneinzelhandel',
#  'kohlenerzeugung',
#  'kohlenexportquote',
#  'kohlenexports',
#  'kohlenfilterung',
#  'kohlenflöze',
#  'kohlenflözen',
#  'kohlenflözgewinnung',
#  'kohlenförderung',
#  'kohlengebiet',
#  'kohlengroßhandels',
#  'kohlengroßhandelsverband',
#  'kohlengruben',
#  'kohlenhalden',
#  'kohlenhandel',
#  'kohlenhandels',
#  'kohlenhandelsgesellschaften',
#  'kohlenhandelsverband',
#  'kohlenhydrate',
#  'kohlenhändler',
#  'kohlenimporte',
#  'kohlenindustrie',
#  'kohlenkontrakte',
#  'kohlenkontrolle',
#  'kohlenkosten',
#  'kohlenkrise',
#  'kohlenlage',
#  'kohlenlieferverträge',
#  'kohlenmarkt',
#  'kohlenmarktes',
#  'kohlenmenge',
#  'kohlenmengen',
#  'kohlenminister',
#  'kohlenmonoxid',
#  'kohlenmonoxiden',
#  'kohlenmonoxidvergiftungen',
#  'kohlenmonoxyd',
#  'kohlennot',
#  'kohlennutzung',
#  'kohlenoxide',
#  'kohlenoxydgas',
#  'kohlenpolitik',
#  'kohlenpott',
#  'kohlenpreis',
#  'kohlenpreise',
#  'kohlenpreisen',
#  'kohlenpreiserhöhung',
#  'kohlenpreises',
#  'kohlenpreisfrage',
#  'kohlenprobleme',
#  'kohlenproduktion',
#  'kohlenprämie',
#  'kohlenreden',
#  'kohlensachverständigen',
#  'kohlenschwemme',
#  'kohlensorten',
#  'kohlenstoff',
#  'kohlenstoffarme',
#  'kohlenstoffarmen',
#  'kohlenstoffbestand',
#  'kohlenstofffreie',
#  'kohlenstofffußabdruck',
#  'kohlenstoffgehalt',
#  'kohlenstoffmarkt',
#  'kohlenstoffsenken',
#  'kohlenstoffspeicherung',
#  'kohlensyndikat',
#  'kohlensyndikats',
#  'kohlensäuredruck',
#  'kohlensäurehaltige',
#  'kohlenutzung',
#  'kohlenverbrauch',
#  'kohlenverbrauchs',
#  'kohlenverkaufs',
#  'kohlenverkaufsgesellschaften',
#  'kohlenversorgung',
#  'kohlenverteuerung',
#  'kohlenvorkommen',
#  'kohlenvorräte',
#  'kohlenwasser',
#  'kohlenwasserstof',
#  'kohlenwasserstoff',
#  'kohlenwasserstoffe',
#  'kohlenwasserstoffen',
#  'kohlenwasserstoffentspannten',
#  'kohlenwirtschaft',
#  'kohlenwirtschaftsjahr',
#  'kohlenzoll',
#  'kohlenzolls',
#  'kohlenzuteilung',
#  'kohlenzuteilungen',
#  'kohlenzüge',
#  'kohlenüberschußproblems',
#  'kohlepartei',
#  'kohlepfennig',
#  'kohlepfennigs',
#  'kohleplafonds',
#  'kohleplan',
#  'kohlepolitik',
#  'kohlepolitische',
#  'kohlepolitischen',
#  'kohlepreis',
#  'kohlepreiserhöhung',
#  'kohleprivilegierung',
#  'kohleproblem',
#  'kohleproblems',
#  'kohleprodukte',
#  'kohleproduktion',
#  'kohleproduzierenden',
#  'kohleprojekten',
#  'kohler',
#  'kohleregionen',
#  'kohlereier',
#  'kohlereserve',
#  'kohlerevier',
#  'kohlereviere',
#  'kohlerevieren',
#  'kohlereviers',
#  'kohlernte',
#  'kohlerunde',
#  'kohlerunden',
#  'kohleschlote',
#  'kohleschutzzoll',
#  'kohlesonderlasten',
#  'kohlestaubverfeuerung',
#  'kohlestrom',
#  'kohlesubvention',
#  'kohlesubventionen',
#  'kohlesubventionierung',
#  'kohletechnologie',
#  'kohletechnologien',
#  'kohletransport',
#  'kohleund',
#  'kohleverbrauch',
#  'kohleverbrauchende',
#  'kohleverbrauchenden',
#  'kohleverbraucher',
#  'kohleverbrauchern',
#  'kohleverbrauchs',
#  'kohleveredelung',
#  'kohleveredelungsprogramm',
#  'kohleveredlung',
#  'kohleveredlungstechniken',
#  'kohlevereinbarung',
#  'kohleverflüssigung',
#  'kohlevergasung',
#  'kohleverkaufs',
#  'kohleverkaufsgesellschaften',
#  'kohleverknappung',
#  'kohlevernichtungspolitik',
#  'kohleversorgung',
#  'kohleverstromung',
#  'kohleverstromungsgesetzes',
#  'kohleverteilungspläne',
#  'kohlevertrag',
#  'kohlevor',
#  'kohlevorkommens',
#  'kohlevorrang',
#  'kohlevorrangpolitik',
#  'kohlevorräte',
#  'kohlewachstum',
#  'kohlewirtschaft',
#  'kohlewirtschaftspolitik',
#  'kohlezeitalter',
#  'kohlezoll',
#  'kohlezollaktion',
#  'kohlezollkontingentgesetz',
#  'kohlezollpolitik',
#  'kohlezolls',
#  'kohlezuteilung',
#  'kohleöl',
#  'kokskohleförderung',
#  'kokskohlehilfe',
#  'kokskohlen',
#  'kokskohlenbeihilfe',
#  'kokskohlenexporte',
#  'kokskohlenregelung',
#  'kokskohlesubvention',
#  'kraftwerkskohlebedarf',
#  'kraftwerkskohlenpreis',
#  'kraftwerkskohlenpreise',
#  'küstenkohlentarife',
#  'nichtkohlerevieren',
#  'nußkohlen',
#  'pechkohlebergbau',
#  'preussagsteinkohlenzeche',
#  'ruhrkohlen',
#  'ruhrkohlenbergbaus',
#  'ruhrkohlenpreisen',
#  'ruhrkohlenverkaufsgesellschaft',
#  'schwarzkohlen',
#  'spitzenkohlenpreise',
#  'steinkohleabsatz',
#  'steinkohleabsatzes',
#  'steinkohlebeihilfe',
#  'steinkohlebeihilfen',
#  'steinkohlebergbau',
#  'steinkohlebergbaus',
#  'steinkohleeinheiten',
#  'steinkohleeinsatz',
#  'steinkohlefinanierungsgesetz',
#  'steinkohlefinanzierung',
#  'steinkohleförderung',
#  'steinkohlehilfen',
#  'steinkohleindustrie',
#  'steinkohlekapazitäten',
#  'steinkohlekompromiß',
#  'steinkohlekraftwerk',
#  'steinkohlekraftwerke',
#  'steinkohlekraftwerken',
#  'steinkohlekraftwerkes',
#  'steinkohlekumpels',
#  'steinkohlen',
#  'steinkohlenabsatzes',
#  'steinkohlenbasis',
#  'steinkohlenbergbau',
#  'steinkohlenbergbaugebiete',
#  'steinkohlenbergbaugebieten',
#  'steinkohlenbergbaus',
#  'steinkohlenbergbausubventionen',
#  'steinkohlenbergwerke',
#  'steinkohlenbezirk',
#  'steinkohleneinheiten',
#  'steinkohleneinsatzes',
#  'steinkohlenergbau',
#  'steinkohlenfinanzierung',
#  'steinkohlenförderung',
#  'steinkohlengebiete',
#  'steinkohlenkraftwerke',
#  'steinkohlenkrise',
#  'steinkohlenkumpeln',
#  'steinkohlenlieferung',
#  'steinkohlenpreis',
#  'steinkohlenproduzenten',
#  'steinkohlenrevier',
#  'steinkohlensorten',
#  'steinkohlenstandortes',
#  'steinkohlensubventionen',
#  'steinkohlentag',
#  'steinkohlenteeröle',
#  'steinkohlenverstromung',
#  'steinkohlenzeche',
#  'steinkohleolitik',
#  'steinkohlereserven',
#  'steinkohlesubvent',
#  'steinkohlesubvention',
#  'steinkohlesubventionen',
#  'steinkohleverstromung',
#  'teinkohlerevieren',
#  'tetrachlorkohlenstoff'}

# %%
kohle_compounds = list(kohle_compounds)

occurences = []
occurences_yes = []
occurences_no = []

for kc in kohle_compounds:
    kc_pars = pars.filter(text__icontains=kc)
    expattern = f"kohle(?!{kc.replace('kohle','')})"
    kc_others = pars.filter(text__iregex=expattern)
    kc_uids = set(kc_pars.values_list('utterance__id',flat=True))
    kc_uids = kc_uids - set(kc_others.values_list('utterance__id',flat=True))
    kc_dos = dos.filter(utterance__in=kc_uids)
    occurences.append(kc_dos.count())
    occurences_yes.append(kc_dos.filter(relevant=1).count())
    occurences_no.append(kc_dos.filter(relevant=2).count())
                          
df = pd.DataFrame({
    "kohle_compound": kohle_compounds,
    "occurences":occurences,
    "yes": occurences_yes,
    "no": occurences_no
}).sort_values('occurences',ascending=False).reset_index(drop=True)

df.head()
# Out:
#     kohle_compound  occurences  yes  no
# 0           kohlen         116   49  66
# 1       kohlekraft          56   56   0
# 2   kohlekraftwerk          54   54   0
# 3  kohlekraftwerke          40   40   0
# 4     kohlenwasser          21    0  21

# %%
df['av'] = df['yes'] - df['no']

# %%
pdf = df[df['occurences']>5].reset_index(drop=True)
fig, ax = plt.subplots(figsize=(8,16))

ax.barh(
    pdf.index, 
    pdf['yes'], 
    align='center',
    color='green', 
    edgecolor='black',
    linewidth=1,
    alpha=0.5
)
ax.barh(
    pdf.index, 
    pdf['no']*-1, 
    align='center',
    color='red', 
    edgecolor='black',
    linewidth=1,
    alpha=0.5
)
ax.set_yticks(pdf.index)
ax.set_yticklabels(pdf['kohle_compound'])
ax.invert_yaxis() 

ax.scatter(pdf['av'],pdf.index, zorder=5)

plt.show()

# %%
pdf = df[df['av']<0].reset_index(drop=True)
fig, ax = plt.subplots(figsize=(8,16))

ax.barh(
    pdf.index, 
    pdf['yes'], 
    align='center',
    color='green', 
    edgecolor='black',
    linewidth=1,
    alpha=0.5
)
ax.barh(
    pdf.index, 
    pdf['no']*-1, 
    align='center',
    color='red', 
    edgecolor='black',
    linewidth=1,
    alpha=0.5
)
ax.set_yticks(pdf.index)
ax.set_yticklabels(pdf['kohle_compound'])
ax.invert_yaxis() 

ax.scatter(pdf['av'],pdf.index, zorder=5)

plt.show()

# %%
kc = "kohlendioxid"
kc_pars = pars.filter(text__icontains=kc)
expattern = f"kohle(?!{kc.replace('kohle','')})"
print(expattern)
kc_others = pars.filter(text__iregex=expattern)
kc_uids = set(kc_pars.values_list('utterance__id',flat=True))
kc_uids = kc_uids - set(kc_others.values_list('utterance__id',flat=True))
kc_dos = dos.filter(utterance__in=kc_uids)

for do in kc_dos.filter(relevant=1):
    print(do.utterance)
    print(do.user)
    print("\n##\n")
    for p in do.utterance.paragraph_set.all():
        print(p.text)
# Out:
# kohle(?!ndioxid)
# Utterance object (1214490)
# leia
#
# ##
#
# Herr Präsident! Meine Damen und Herren! Die Opposition macht zwar viel Wind; aber davon dreht sich in Deutschland noch kein einziges Windrad.
# Mit unserem Energiekonzept ist das anders. Es bietet erstmals seit langem einen belastbaren Fahrplan für die Energieversorgung von morgen. Das haben Rot-Grün und all unsere Vorgängerregierungen nicht geschafft.
# Wir haben das geschafft. Ich möchte mich beim Kollegen Röttgen für die gute, sorgfältige Zusammenarbeit, die zu diesem Energiekonzept geführt hat, ausdrücklich bedanken.
# re u E d n p s Ih e n a u n S D In ra g Ic V te g D h d le b m d S d d is is A v d Es geht dabei um den Weg ins Zeitalter der erneuerban Energien, es geht um aktiven Klimaschutz, es geht m Versorgungssicherheit, und es geht um bezahlbare nergiepreise. Ein wesentlicher Aspekt ist der Ausbau er Netze. Ohne Netzausbau gibt es kein Zeitalter der ereuerbaren Energien.
# Das wissen auch die Damen und Herren von der Oposition. Hier im Bundestag bekennen Sie sich dazu chön brav. Aber vor Ort haben das viele von Ihnen und ren politischen Freunden sehr schnell vergessen. Wenn s zum Beispiel um den Bau notwendiger Hochspanungsleitungen und Speicher geht, sind viele von Ihnen n vorderster Front bei den Blockierern dabei. Das ist nredlich, das ist unverantwortlich.
# Wir werden in Deutschland circa 3 500 Kilometer eue Leitungen brauchen; das ist dreieinhalbmal die trecke von Füssen nach Flensburg.
# as betrifft den Bund, die Länder und die Kommunen. Stuttgart und beim Berliner Flughafen sehen wir gede, dass große Infrastrukturprojekte mit den Bürgern emeinsam geplant und durchgeführt werden müssen. h rege daher einen nationalen Pakt für neue Netze an. orbild könnte der Ausbildungspakt sein. Ziel des Paks soll es sein, die Bürger beim Netzausbau für das reenerative Zeitalter adäquat einzubeziehen.
# ie beim Bundeswirtschaftsministerium bereits besteende Netzplattform könnte die Basis für einen Dialog er unterschiedlichen Beteiligten und für einen sinnvoln gemeinsamen Weg sein. Für das im Kern marktwirtschaftliche Energiekonzept rauchen wir die Unternehmen. Wir brauchen Unternehen, die moderne Kraftwerke bauen, die die Vernetzung er Windräder im Norden mit den Stromabnehmern im üden zuverlässig umsetzen können und die die notwenigen Energie- und Kohlendioxidspeicher bauen. Auf ie private Initiative dieser Unternehmen setzen wir. Das t die richtige Balance zwischen Markt und Staat. Das t soziale Marktwirtschaft.
# uf die Stärken der sozialen Marktwirtschaft können wir ertrauen. Das zeigt auch das derzeitige Wachstumswuner in Deutschland.
# )(B) Der Netzausbau ist aber nur ein Teil des Gesamtpakets. Zu dem Gesamtpaket gehört auch eine neue Energieaußenpolitik; denn nicht nur in Deutschland verändert sich die Energiepolitik. Von Afrika bis Asien wollen Staaten die erneuerbaren Energien ausbauen. Viele Staaten, zum Beispiel Russland, wollen ihre Energieeffizienz erhöhen. Mit der Russisch-Deutschen Energie-Agentur, rudea, kommen wir gut voran. Wir wollen neue Exportchancen frühzeitig nutzen. Wir werden das mit der Exportinitiative Erneuerbare Energien, mit der Exportinitiative Energieeffizienz und mit den allgemeinen Instrumentarien der Außenwirtschaftspolitik, zum Beispiel den Hermesbürgschaften, aktiv flankieren. Klar ist, dass der Klimawandel mit nationalen Alleingängen nicht aufzuhalten ist. Alle müssen ihren Beitrag leisten. Aber nicht nur beim Klimaschutz brauchen wir starke Partner in der Welt. Bis auf Weiteres bleiben wir auf den Import fossiler Energieträger wie Öl und Gas angewiesen. Deshalb arbeiten wir eng mit einigen Partnerländern zusammen. Es gibt nicht nur die Modernisierungspartnerschaft mit Russland, sondern wir haben auch Energiepartnerschaften mit Katar, Nigeria und der Türkei auf den Weg gebracht. Das schafft eine verlässliche Grundlage für die deutsche Industrie, für die deutsche gewerbliche Wirtschaft. Es hilft auch den Partnerländern bei ihrer Entwicklung und trägt dazu bei, die Lieferrisiken zu streuen. Meine Damen und Herren, mit dem Energiekonzept ebnen wir den Weg in das Zeitalter der regenerativen Energien. Als Leitkonzept kann es Nachahmer in Europa und weltweit finden. Wir sollten uns jetzt auf die Umsetzung konzentrieren und nicht erneut die Debatten von gestern und vorgestern führen.
